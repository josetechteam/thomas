# %% [markdown]
# # Disk usage
# ## COOL

# %%
! ls
# Out:
# disk usage.ipynb  Makefile  mortgage.ipynb  ruby101.ipynb

# %%
! du -hd 1 ~
# Out:
# 92K	/home/tyler/.cinnamon
# 8.0K	/home/tyler/.gnupg
# 104K	/home/tyler/.ipython
# 16K	/home/tyler/.ipynb_checkpoints
# 28K	/home/tyler/.dbus
# 460K	/home/tyler/.config
# 4.0K	/home/tyler/Music
# 4.0K	/home/tyler/Desktop
# 88M	/home/tyler/.local
# 520K	/home/tyler/.gimp-2.8
# 4.0K	/home/tyler/Pictures
# 4.0K	/home/tyler/Documents
# 36M	/home/tyler/.mozilla
# 4.0K	/home/tyler/Downloads
# 4.0K	/home/tyler/.gnome2
# 4.0K	/home/tyler/Public
# 8.0K	/home/tyler/.linuxmint
# 148M	/home/tyler/opt
# 8.0K	/home/tyler/.vnc
# 20M	/home/tyler/.bundle
# 8.0K	/home/tyler/.jupyter
# du: cannot read directory '/home/tyler/.cache/dconf': Permission denied
# 158M	/home/tyler/.cache
# 4.0K	/home/tyler/Templates
# 12K	/home/tyler/.ssh
# 4.0K	/home/tyler/Videos
# 136K	/home/tyler/.gem
# 4.0K	/home/tyler/.gconf
# 450M	/home/tyler

# %%
# !du -hd 1 /
# Out:
# 16M	/bin
# du: cannot read directory '/var/lib/apt/lists/partial': Permission denied
# du: cannot read directory '/var/lib/polkit-1': Permission denied
# du: cannot read directory '/var/lib/lightdm': Permission denied
# du: cannot read directory '/var/lib/udisks2': Permission denied
# du: cannot read directory '/var/lib/colord/.cache': Permission denied
# du: cannot read directory '/var/cache/apt/archives/partial': Permission denied
# du: cannot read directory '/var/cache/cups': Permission denied
# du: cannot read directory '/var/cache/ldconfig': Permission denied
# du: cannot read directory '/var/spool/rsyslog': Permission denied
# du: cannot read directory '/var/spool/cron/crontabs': Permission denied
# du: cannot read directory '/var/spool/cups': Permission denied
# du: cannot read directory '/var/tmp/systemd-private-0dc9c9df023d447fbd7a8e058ba9be6c-rtkit-daemon.service-8GuU8y': Permission denied
# ...

# %%
# ! sudo du -hd 1 /

# %%
! sudo baobab

# %%
! sudo du -hd 1 /
